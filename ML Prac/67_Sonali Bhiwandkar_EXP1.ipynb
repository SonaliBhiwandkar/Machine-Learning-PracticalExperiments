# %%
print("Name : Sonali Niketan Bhiwandkar,","Roll No : ",67)
# Out:
# Name : Sonali Niketan Bhiwandkar, Roll No :  67

# %%
Name= "Sonali Niketan Bhiwandkar"
RollNo= 67

# %%
print(Name)
# Out:
# Sonali Niketan Bhiwandkar

# %%
print(RollNo)
# Out:
# 67

# %%
type(Name)
# Out:
# str

# %%
type(RollNo)
# Out:
# int

# %%
x= str(67) #x will be '67'
print(x)
print(type(x))
# Out:
# 67
# <class 'str'>

# %%
y= int(67) #y will be '67'
print(y)
print(type(y))
# Out:
# 67
# <class 'int'>

# %%
z= float(67) #z will be '67.0'
print(z)
print(type(z))
# Out:
# 67.0
# <class 'float'>

# %%
x,y,z='Sonali','Niketan','Bhiwandkar'
print(x)
print(y)
print(z)
# Out:
# Sonali
# Niketan
# Bhiwandkar

# %%
fruits=['cherry','banana','orange']
x,y,z=fruits
print(fruits)
# Out:
# ['cherry', 'banana', 'orange']

# %%
print(x)
# Out:
# cherry

# %%
x,y,z='Sonali','Niketan','Bhiwandkar'
print(x+y+z)
# Out:
# SonaliNiketanBhiwandkar

# %%
x,y,z='Sonali ','Niketan ','Bhiwandkar'
print(x+y+z)
# Out:
# Sonali Niketan Bhiwandkar

# %%
x = "awesome"

def myfunc():
  x = "fantastic"
  print("Python is " + x)

myfunc()
print("Python is " + x)
# Out:
# Python is fantastic
# Python is awesome

# %%
import numpy as np

# %%
arr=np.array([1,2,3,4,5])
arr
# Out:
# array([1, 2, 3, 4, 5])

# %%
type(arr)
# Out:
# numpy.ndarray

# %%
print(arr[0])
# Out:
# 1

# %%
print(arr[0]+arr[1])
# Out:
# 3

# %%
print(arr[1:3])
# Out:
# [2 3]

# %%
print(arr.shape)
# Out:
# (5,)

# %%
array1= np.array([3, 2, 0, 1])

# %%
print(np.sort(array1))
# Out:
# [0 1 2 3]

# %%
import pandas as pd

mydataset = {
  'cars': ["mercedes", "suzuki", "Ford"],
  'passings': [3, 7, 2]
}

df= pd.DataFrame(mydataset)
print(df)
# Out:
#        cars  passings
# 0  mercedes         3
# 1    suzuki         7
# 2      Ford         2

# %%
new_df = df.dropna()

# %%
new_df
# Out:
#        cars  passings
# 0  mercedes         3
# 1    suzuki         7
# 2      Ford         2

# %%
import matplotlib.pyplot as plt

xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints)
plt.show()
