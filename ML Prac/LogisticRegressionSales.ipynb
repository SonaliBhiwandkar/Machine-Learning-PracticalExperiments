# %%
import numpy as np

# %%
# Define the data
x = np.array([2006, 2007, 2008, 2009, 2010])
sales = np.array([40, 56, 78, 80, 40])

# %%
# Calculate the trend line using the least squares method
A = np.vstack([years, np.ones(len(years))]).T
m, c = np.linalg.lstsq(A, sales, rcond=None)[0]

# %%
# Print the equation of the trend line

# %%
print("Slope (m) : ", m)
# Out:
# Slope (m) :  2.4000000000004174

# %%
print("Intercept (c) : ",c)
# Out:
# Intercept (c) :  -4760.400000000838
